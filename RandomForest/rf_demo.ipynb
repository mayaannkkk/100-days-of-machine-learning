# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.376700  0.747071 -1.731513  0.555101  0.904728       1
# 1  1.799495 -1.661721  0.541303 -0.982455 -1.791031       0
# 2  0.650329 -0.500071 -0.028028  0.149398  0.907148       1
# 3  2.953363 -0.891828  1.400856 -0.214524 -1.330722       0
# 4  0.589163  0.550246 -1.940280  0.866159  2.101888       1

# %%
def sample_row(df,percent):
    return df.sample(int(percent*df.shape[0]),replace=True)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
df1 = sample_row(df,0.2)

# %%
df2 = sample_row(df,0.2)

# %%
df3 = sample_row(df,0.2)

# %%
df1
# Out:
#         col1      col2      col3      col4      col5  target
# 70  0.092915 -0.213924 -0.700907  0.630246 -0.025864       0
# 23  1.238587  2.196692  1.003142 -0.251775 -3.417594       1
# 98  1.255996  2.521521 -2.945844 -0.138549 -2.087499       1
# 18 -1.717171 -1.675279 -1.060456 -1.855809  1.596624       0
# 57 -0.229153 -1.631115 -1.228603  1.537035  1.868855       1
# 48  0.850636  0.151885 -0.428992  1.880765  0.259386       1
# 71  2.508492  3.605285 -2.057621  0.991171 -3.210833       1
# 64 -0.025586  1.172935 -2.540088  1.160155 -4.095382       1
# 86  0.153420 -0.149785 -0.777671  0.708117  1.058467       0
# 70  0.092915 -0.213924 -0.700907  0.630246 -0.025864       0
# 36 -3.330448 -2.335374  0.745398 -4.224125  2.296417       0
# 73 -0.709079 -0.454657  0.287537  1.655462 -3.398300       1
# 98  1.255996  2.521521 -2.945844 -0.138549 -2.087499       1
# 86  0.153420 -0.149785 -0.777671  0.708117  1.058467       0
# ...

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.6, 0.875, 'x[1] <= -0.033\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.4, 0.625, 'x[3] <= 1.131\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.5, 0.75, 'True  '),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6, 0.375, 'x[4] <= 1.889\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.7, 0.75, '  False')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 0.29\ngini = 0.42\nsamples = 20\nvalue = [14, 6]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.4, 0.875, 'x[4] <= -1.678\ngini = 0.48\nsamples = 20\nvalue = [12, 8]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.30000000000000004, 0.75, 'True  '),
#  Text(0.6, 0.625, 'x[4] <= -0.754\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.5, 0.75, '  False'),
#  Text(0.4, 0.375, 'x[3] <= 1.708\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8, 0.375, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]')]

# %%
clf1.predict(np.array([3.459765,	1.824612,	-0.743747,	3.037009,	2.679200]).reshape(1,5))
# Out:
# C:\Users\MAYANK GOYAL\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([3.459765,	1.824612,	-0.743747,	3.037009,	2.679200]).reshape(1,5))
# Out:
# C:\Users\MAYANK GOYAL\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([3.459765,	1.824612,	-0.743747,	3.037009,	2.679200]).reshape(1,5))
# Out:
# C:\Users\MAYANK GOYAL\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import random
def sample_feature(df,percent):
    cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
    new_df = df[cols]
    new_df['target'] = df['target']
    return new_df

# %%
df1 = sample_feature(df,0.5)
# Out:
# C:\Users\MAYANK GOYAL\AppData\Local\Temp\ipykernel_21524\211426091.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df2 = sample_feature(df,0.5)
# Out:
# C:\Users\MAYANK GOYAL\AppData\Local\Temp\ipykernel_21524\211426091.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df3 = sample_feature(df,0.5)
# Out:
# C:\Users\MAYANK GOYAL\AppData\Local\Temp\ipykernel_21524\211426091.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df1
# Out:
#         col3      col4  target
# 0  -1.731513  0.555101       1
# 1   0.541303 -0.982455       0
# 2  -0.028028  0.149398       1
# 3   1.400856 -0.214524       0
# 4  -1.940280  0.866159       1
# ..       ...       ...     ...
# 95 -1.089904  1.877740       0
# 96 -1.803771  0.876403       1
# 97  0.242889  2.212083       1
# 98 -2.663841  1.459706       1
# 99 -1.399170 -0.109180       0
#
# [100 rows x 3 columns]

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(clf1)
# Out:
# [Text(0.690677966101695, 0.9615384615384616, 'x[1] <= 2.289\ngini = 0.5\nsamples = 100\nvalue = [51, 49]'),
#  Text(0.6228813559322034, 0.8846153846153846, 'x[1] <= -0.564\ngini = 0.495\nsamples = 87\nvalue = [39, 48]'),
#  Text(0.6567796610169492, 0.9230769230769231, 'True  '),
#  Text(0.5889830508474576, 0.8076923076923077, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6567796610169492, 0.8076923076923077, 'x[1] <= 1.731\ngini = 0.485\nsamples = 82\nvalue = [34, 48]'),
#  Text(0.4830508474576271, 0.7307692307692307, 'x[1] <= 0.442\ngini = 0.468\nsamples = 67\nvalue = [25, 42]'),
#  Text(0.3898305084745763, 0.6538461538461539, 'x[1] <= 0.35\ngini = 0.499\nsamples = 23\nvalue = [12, 11]'),
#  Text(0.3559322033898305, 0.5769230769230769, 'x[0] <= 1.372\ngini = 0.499\nsamples = 21\nvalue = [10, 11]'),
#  Text(0.3220338983050847, 0.5, 'x[0] <= 0.191\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.3977272727272727, 0.9444444444444444, 'x[1] <= -0.446\ngini = 0.5\nsamples = 100\nvalue = [51, 49]'),
#  Text(0.18181818181818182, 0.8333333333333334, 'x[0] <= 0.953\ngini = 0.105\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.2897727272727273, 0.8888888888888888, 'True  '),
#  Text(0.13636363636363635, 0.7222222222222222, 'x[0] <= 0.82\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.09090909090909091, 0.6111111111111112, 'x[1] <= -0.883\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.045454545454545456, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.13636363636363635, 0.5, 'x[0] <= -0.078\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09090909090909091, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18181818181818182, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18181818181818182, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.39285714285714285, 0.9444444444444444, 'x[1] <= -0.069\ngini = 0.5\nsamples = 100\nvalue = [51, 49]'),
#  Text(0.14285714285714285, 0.8333333333333334, 'x[0] <= 0.319\ngini = 0.19\nsamples = 47\nvalue = [42, 5]'),
#  Text(0.26785714285714285, 0.8888888888888888, 'True  '),
#  Text(0.07142857142857142, 0.7222222222222222, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(0.21428571428571427, 0.7222222222222222, 'x[1] <= -0.37\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.14285714285714285, 0.6111111111111112, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.2857142857142857, 0.6111111111111112, 'x[1] <= -0.265\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.21428571428571427, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35714285714285715, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6428571428571429, 0.8333333333333334, 'x[0] <= -0.447\ngini = 0.282\nsamples = 53\nvalue = [9, 44]'),
# ...

# %%
clf1.predict(np.array([0.149398,	-0.500071]).reshape(1,2))
# Out:
# C:\Users\MAYANK GOYAL\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([0.149398,	-0.500071]).reshape(1,2))
# Out:
# C:\Users\MAYANK GOYAL\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([0.149398,	-0.500071]).reshape(1,2))
# Out:
# C:\Users\MAYANK GOYAL\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
