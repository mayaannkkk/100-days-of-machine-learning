# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('titanic_toy.csv')

# %%
df.isnull().mean()*100
# Out:
# Age         19.865320
# Fare         5.050505
# Family       0.000000
# Survived     0.000000
# dtype: float64

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
X= df.drop('Survived',axis=1)
y= df['Survived']
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train['age_mean'] = X_train['Age'].fillna(X_train['Age'].mean())
X_train['age_median'] = X_train['Age'].fillna(X_train['Age'].median())
X_train['Fare_mean'] = X_train['Fare'].fillna(X_train['Fare'].mean())
X_train['Fare_median'] = X_train['Fare'].fillna(X_train['Fare'].median())

# %%
X_train.sample(5)
# Out:
#       Age     Fare  Family   age_mean  age_median  Fare_mean  Fare_median
# 105  28.0   7.8958       0  28.000000       28.00     7.8958       7.8958
# 804  27.0   6.9750       0  27.000000       27.00     6.9750       6.9750
# 619  26.0  10.5000       0  26.000000       26.00    10.5000      10.5000
# 121   NaN   8.0500       0  29.785904       28.75     8.0500       8.0500
# 859   NaN   7.2292       0  29.785904       28.75     7.2292       7.2292

# %%
X_train['Fare'].mean()
# Out:
# np.float64(32.61759689349112)

# %%
X_train['Age'].var(),X_train['age_mean'].var(),X_train['age_median'].var(),X_train['Fare'].var(),X_train['Fare_mean'].var(),X_train['Fare_median'].var()
# Out:
# (np.float64(204.34951339046142),
#  np.float64(161.81262452718676),
#  np.float64(161.98956633460548),
#  np.float64(2448.1979137063163),
#  np.float64(2324.2385256705534),
#  np.float64(2340.09102197536))

# %%
sns.kdeplot(X_train['Age'])
sns.kdeplot(X_train['age_median'],color='r')
sns.kdeplot(X_train['age_mean'],color='blue')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(X_train['Fare'])
sns.kdeplot(X_train['Fare_median'],color='r')
sns.kdeplot(X_train['Fare_mean'],color='blue')
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
X_train.cov()
# Out:
#                     Age         Fare     Family    age_mean  age_median  \
# Age          204.349513    70.719262  -6.498901  204.349513  204.349513
# Fare          70.719262  2448.197914  17.258917   55.603719   57.957599
# Family        -6.498901    17.258917   2.735252   -5.146106   -5.112563
# age_mean     204.349513    55.603719  -5.146106  161.812625  161.812625
# age_median   204.349513    57.957599  -5.112563  161.812625  161.989566
# Fare_mean     66.665205  2448.197914  16.385048   52.788341   55.023037
# Fare_median   64.858859  2448.197914  16.476305   51.358000   53.553455
#
#                Fare_mean  Fare_median
# Age            66.665205    64.858859
# Fare         2448.197914  2448.197914
# Family         16.385048    16.476305
# age_mean       52.788341    51.358000
# age_median     55.023037    53.553455
# Fare_mean    2324.238526  2324.238526
# Fare_median  2324.238526  2340.091022

# %%
X_train.corr()
# Out:
#                   Age      Fare    Family  age_mean  age_median  Fare_mean  \
# Age          1.000000  0.092644 -0.299113  1.000000    1.000000   0.090156
# Fare         0.092644  1.000000  0.208268  0.088069    0.091757   1.000000
# Family      -0.299113  0.208268  1.000000 -0.244610   -0.242883   0.205499
# age_mean     1.000000  0.088069 -0.244610  1.000000    0.999454   0.086078
# age_median   1.000000  0.091757 -0.242883  0.999454    1.000000   0.089673
# Fare_mean    0.090156  1.000000  0.205499  0.086078    0.089673   1.000000
# Fare_median  0.087356  1.000000  0.205942  0.083461    0.086982   0.996607
#
#              Fare_median
# Age             0.087356
# Fare            1.000000
# Family          0.205942
# age_mean        0.083461
# age_median      0.086982
# Fare_mean       0.996607
# Fare_median     1.000000

# %%
X_train[['Age','age_mean','age_median']].plot(kind='box')
# Out:
# <Axes: >

# %%
X_train[['Fare','Fare_mean','Fare_median']].plot(kind='box')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
X= df.drop('Survived',axis=1)
y= df['Survived']

X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.isnull().sum()
# Out:
# Age       148
# Fare       36
# Family      0
# dtype: int64

# %%
trf = ColumnTransformer([
    ('imp1',SimpleImputer(strategy='mean'),['Age']),
    ('imp2',SimpleImputer(strategy='median'),['Fare'])
],remainder='passthrough')

# %%
trf.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imp1', SimpleImputer(), ['Age']),
#                                 ('imp2', SimpleImputer(strategy='median'),
#                                  ['Fare'])])

# %%
trf.named_transformers_['imp2'].statistics_
# Out:
# array([14.4583])

# %%
X_train_new=trf.transform(X_train)
X_test_new=trf.transform(X_test)

# %%
X_train_new = pd.DataFrame(X_train_new,columns=X_train.columns)

# %%
X_train_new.isnull().sum()
# Out:
# Age       0
# Fare      0
# Family    0
# dtype: int64
