# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic_toy.csv",usecols=["Age","Fare","Survived"])

# %%
df.head()
# Out:
#     Age     Fare  Survived
# 0  22.0   7.2500         0
# 1  38.0  71.2833         1
# 2  26.0   7.9250         1
# 3  35.0  53.1000         1
# 4  35.0   8.0500         0

# %%
from sklearn.model_selection import train_test_split

# %%
X= df.drop("Survived",axis=1)
y= df["Survived"]

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train["Age_imp"] = X_train["Age"]
X_test["Age_imp"] = X_test["Age"]

# %%
X_train.isnull().sum()
# Out:
# Age        124
# Fare        30
# Age_imp    124
# dtype: int64

# %%
X_train['Age_imp'][X_train['Age_imp'].isnull()]
# Out:
# 650   NaN
# 181   NaN
# 334   NaN
# 28    NaN
# 783   NaN
#        ..
# 330   NaN
# 214   NaN
# 466   NaN
# 121   NaN
# 270   NaN
# Name: Age_imp, Length: 124, dtype: float64

# %%
X_train['Age_imp'][X_train['Age_imp'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
X_test['Age_imp'][X_test['Age_imp'].isnull()] = X_train['Age'].dropna().sample(X_test['Age'].isnull().sum()).values
# Out:
# C:\Users\MAYANK GOYAL\AppData\Local\Temp\ipykernel_23996\316057343.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
X_train.sample(5)
# Out:
#       Age     Fare  Age_imp
# 145  19.0  36.7500     19.0
# 559  36.0  17.4000     36.0
# 156  16.0   7.7333     16.0
# 761  41.0   7.1250     41.0
# 166   NaN  55.0000     32.0

# %%
sns.kdeplot(X_train["Age"])
sns.kdeplot(X_train["Age_imp"])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
X_train['Age'].dropna().sample(X_test['Age'].isnull().sum()).values
# Out:
# array([38.  , 51.  , 16.  ,  0.75, 33.  , 32.  , 36.  , 28.  , 30.  ,
#        28.  ,  7.  , 15.  , 80.  , 28.  ,  3.  , 26.  , 30.  , 30.  ,
#        18.  , 33.  ,  2.  , 21.  , 45.  , 20.  , 44.  , 54.  , 38.  ,
#        16.  , 28.  , 21.  , 58.  , 39.  , 52.  , 24.  , 34.  , 19.  ,
#        27.  , 26.  , 54.  , 27.  , 24.  , 23.  , 39.  , 31.  , 26.  ,
#        58.  , 25.  , 33.  , 25.  , 22.  , 42.  , 20.  , 35.  ])

# %%
X_train["Age"].var(), X_train["Age_imp"].var()
# Out:
# (np.float64(211.9518806464334), np.float64(212.04928883217292))

# %%
df1 = pd.read_csv("house-train.csv",usecols=["SalePrice","GarageQual",'FireplaceQu'])

# %%
df1.shape
# Out:
# (1460, 3)

# %%
X1= df1
y1= df1["SalePrice"]

# %%
X_train, X_test, y_train, y_test= train_test_split(X1,y1,test_size=0.3,random_state=42)

# %%
X_train["FireplaceQu_imp"] = X_train["FireplaceQu"]
X_test["FireplaceQu_imp"] = X_test["FireplaceQu"]
X_test["GarageQual_imp"] = X_test["GarageQual"]
X_train["GarageQual_imp"] = X_train["GarageQual"]

# %%
X_test
# Out:
#      FireplaceQu GarageQual  SalePrice GarageQual_imp FireplaceQu_imp
# 892          NaN         TA     154500             TA             NaN
# 1105          TA         TA     325000             TA              TA
# 413           Gd         TA     115000             TA              Gd
# 522           Gd         TA     159000             TA              Gd
# 1036          Ex         TA     315500             TA              Ex
# ...          ...        ...        ...            ...             ...
# 331          NaN         TA     139000             TA             NaN
# 323          NaN         Fa     126175             Fa             NaN
# 650          NaN         TA     205950             TA             NaN
# 439          NaN         TA     110000             TA             NaN
# 798           Gd         TA     485000             TA              Gd
#
# [438 rows x 5 columns]

# %%
X_test["GarageQual"]
# Out:
# 892     TA
# 1105    TA
# 413     TA
# 522     TA
# 1036    TA
#         ..
# 331     TA
# 323     Fa
# 650     TA
# 439     TA
# 798     TA
# Name: GarageQual, Length: 438, dtype: object

# %%
X_train["FireplaceQu_imp"][X_train["FireplaceQu_imp"].isnull()] = X_train["FireplaceQu"].dropna().sample(X_train["FireplaceQu_imp"].isnull().sum()).values
X_test["FireplaceQu_imp"][X_test["FireplaceQu_imp"].isnull()] = X_test["FireplaceQu"].dropna().sample(X_test["FireplaceQu_imp"].isnull().sum()).values
X_train["GarageQual_imp"][X_train["GarageQual_imp"].isnull()] = X_train["GarageQual"].dropna().sample(X_train["GarageQual_imp"].isnull().sum()).values
X_test["GarageQual_imp"][X_test["GarageQual_imp"].isnull()] = X_train["GarageQual"].dropna().sample(X_test["GarageQual_imp"].isnull().sum()).values
# Out:
# C:\Users\MAYANK GOYAL\AppData\Local\Temp\ipykernel_23996\960219985.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
X_test.sample(10)
# Out:
#      FireplaceQu GarageQual  SalePrice GarageQual_imp FireplaceQu_imp
# 203           Gd         TA     149000             TA              Gd
# 514          NaN         Po      96500             Po              Gd
# 405           TA         TA     150000             TA              TA
# 198          NaN        NaN     104000             TA              Gd
# 350           Gd         TA     318061             TA              Gd
# 1322          TA         TA     190000             TA              TA
# 482           Gd         Fa     155000             Fa              Gd
# 1398         NaN         TA     138000             TA              Gd
# 1392          Po         TA     123000             TA              Po
# 363          NaN         TA     118000             TA              Po

# %%
for category in X_train['FireplaceQu'].dropna().unique():
    sns.kdeplot(X_train[X_train['FireplaceQu'] == category]['SalePrice'],label=category)
